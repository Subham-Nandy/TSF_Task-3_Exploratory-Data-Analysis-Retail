# %% [markdown]
# #Importing dataset and libraries

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/MY DATASET/SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %% [markdown]
# #Exploratory Data Analysis

# %%
sns.set(style="white")

# %% [markdown]
# **Visualization of Sales with respect to each category**

# %%
sns.boxplot(x='Category', y='Sales', data=data)
plt.yscale('log')
plt.show()

# %% [markdown]
# Inference: Here we can see that sales of products related to office supplies are on an average lower than the sales of other two categories.

# %% [markdown]
# **Visualisation of profits incurred from each category**

# %%
sns.boxplot(x='Category', y='Profit', data=data)
plt.show()

# %% [markdown]
# Inference:There are lot of outliers in the data due to which the boxbplots are not comprehensible. so we need to compare sales and profit using any other visualisation tool.

# %% [markdown]
# **Comparison of Sales and Profit with respect to each category of products**

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.barplot(x='Category', y='Sales', data=data, estimator=np.median)
plt.title("Sales")
plt.subplot(1,2,2)
sns.barplot(x='Category', y='Profit', data=data, estimator=np.median)
plt.title("Profit")
plt.show()

# %% [markdown]
# Inference: So, we can see that although the sales of furnitures are high but they incurr least profit compared to office supplies and technology categories. This may be due to the high shipping cost of the furnitures¶
# So, High sales does not always ensure higher profits. They depend on other factors

# %% [markdown]
# **Evaluation of profits incurred with respect to shipping modes and categories**

# %%
plt.figure(num=None, figsize=(15,8), dpi=80, facecolor='w', edgecolor='k')
sns.barplot(x='Ship Mode', y='Profit', hue='Category', data=data, estimator=np.median)
plt.show()

# %% [markdown]
# Inference: So, we can see that for all types of shipping modes also, prodcuts related to technology incurrs more profits.

# %% [markdown]
# **Which shipping mode individually is more profitable:**

# %%
sns.barplot(x='Ship Mode', y='Profit', data=data, estimator=np.median)
plt.show()

# %% [markdown]
# Inference: Thus, all the shipping modes are more or less equal in terms of profit. However, second class ship mode is little better than the other modes in terms of profit

# %%
plt.figure(num=None, figsize=(15,8), dpi=80, facecolor='w', edgecolor='k')
sns.barplot(x='Segment', y='Profit', hue='Category', data=data, estimator=np.median)
plt.show()

# %% [markdown]
# Inference: Profit of technology products is maximum for Home office and more than office supplies and furnitures for all customer segments.

# %% [markdown]
# **Analysis of sales on product sub-categories :**

# %%
plt.figure(figsize=(20,6))
sns.countplot(y="Sub-Category", data=data)
plt.show()

# %% [markdown]
# Inference : We can see that Binders have maximum sales and Copiers have fewer no. of orders.
#
# N.B.- What is to be noted here is that due to the presence of many outliers in the data, median estimator is used while plotting the barplots

# %% [markdown]
# **Visualizing sales across the regions :**

# %%
plt.figure(num=None, figsize=(15,8), dpi=80, facecolor='w', edgecolor='k')
sns.barplot(x='Region', y='Sales', data=data, estimator=np.median)
plt.show()

# %% [markdown]
# OVERALL OPINION AS A BUSINESS OWNER :
#
# 1. Our company need to work on how to increase the sales of office suplies like machines, copiers.
# 2. It is urgently required to find means of cheaper transport and shipping of furnitures so as to increase the profits incurred from them.
# 3. Little focus is required on increasing sales in Central region.
